# %% [markdown]
# <h1 style='font-size:40px'> Infinite Sequences and Series </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Essa seção lidará com sequências e séries de números.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> 11.1 Sequences</h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Uma sequência seria uma ordenação de números. $a_{n}$ corresponderia ao $n$-ésimo valor da sequência.
#         </li>
#         <li>
#             Nessa seção, todas as sequências serão <i> infinitas</i>. Podemos defini-las de diversas maneiras, como $\{a_{1},a_{2},\ldots\}$,$\{a_{n}\}$,$\{a_{n}\}_{n=1}^{\infty}$.
#         </li>
#     </ul>
# </div>

# %%
! git add .
! git commit -am 'Continuar de Example III' 
! git push
# Out:
# [master c6e1786] Iniciar exs. seção 10.5
#  2 files changed, 26 insertions(+), 24 deletions(-)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 700 bytes | 700.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/felipesveiga/Calculus.git
#    d66e44e..c6e1786  master -> master

# %% [markdown]
# <p style='color:red'> Iniciei capítulo 11; Continuar de Example III
