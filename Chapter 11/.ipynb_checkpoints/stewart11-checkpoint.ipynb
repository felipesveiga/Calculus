# %% [markdown]
# <h1 style='font-size:40px'> Infinite Sequences and Series </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Essa seção lidará com sequências e séries de números.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> 11.1 Sequences</h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Uma sequência seria uma ordenação de números. $a_{n}$ corresponderia ao $n$-ésimo valor da sequência.
#         </li>
#         <li>
#             Nessa seção, todas as sequências serão <i> infinitas</i>. Podemos defini-las de diversas maneiras, como $\{a_{1},a_{2},\ldots\}$,$\{a_{n}\}$,$\{a_{n}\}_{n=1}^{\infty}$. Repare que $n$ sempre será um positivo maior ou igual a 1!
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'>
#     Notações
# </h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Podemos representar os itens de uma sequência como pontos $(n,a_{n}),n \in\mathbb{Z}_{\geq1}$, inclusive os plotando no plano cartesiano!
#         </li>
#      </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         <img src='sequence-limit.png'>
#         <figcaption style='font-size:15px'>
#             Exemplo de uma representação de sequência no plano
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Certas sequências (como a acima) também podem demonstrar <i> covergência</i> a um valor, conforme $n\to\infty$.
#         </li>
#         <li>
#             No caso, dizemos que essas sequências são <strong>convergentes</strong>, enquanto que as que não, <strong> divergentes</strong>.
#         </li>
#      </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         $\lim_{n\to\infty}{a_{n}}=L$
#         <figcaption style='font-size:15px'>
#             Notação para convergência de uma sequência
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             O livro também fornece uma definição mais rigorosa sobre o conceito de convergência de uma sequência, muito semelhante com a ideia de limites exatos.
#         </li>
#      </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         <img src='convergence-exact.png'>
#         <figcaption style='font-size:15px'>
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         <img src='convergence-exact-chart.png'>
#         <figcaption style='font-size:15px'>
#             Ilustração do livro que auxilia a compreensão do conceito exato de convergência.
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         <img src='divergence-exact.png'>
#         <figcaption style='font-size:15px'>
#             O livro nos dá também uma definição formal de divergência de séries.
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             É possível que sequências possam ser exatamente representadas por funções $f(x)$ (quando $x$ é um inteiro).
#         </li>
#         <li>
#             Nessa situação, o livro nos apresenta a seguinte propriedade:
#         </li>
#      </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         <img src='function-sequences.png'>
#         <figcaption style='font-size:15px'>
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'>
#     Propriedades
# </h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Somos apresentados também a uma série de propriedades sobre sequências (especialmente as convergentes), que se assemelham bastante com às de funções.
#         </li>
#      </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         <img src='sequences-properties.png'>
#         <figcaption style='font-size:15px'>
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         <img src='squeeze-sequences.png'>
#         <figcaption style='font-size:15px'>
#             O Squeeze Theorem também se aplica a sequências!
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         <img src='sequences-absolute.png'>
#         <figcaption style='font-size:15px'>
#             Teorema relacionado ao valor absoluto, cuja prova é feita no exercício 75 da seção.
#         </figcaption>
#     </center>
# </figure>

# %%
! git add .
! git commit -am 'Example IV' 
! git push
# Out:
# [master e8e512a] Continuar de grifado p. 677
#  3 files changed, 156 insertions(+), 24 deletions(-)
#  create mode 100644 Chapter 11/sequence-limit.png
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 5.62 KiB | 5.62 MiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/felipesveiga/Calculus.git
#    f7411e1..e8e512a  master -> master

# %% [markdown]
# <p style='color:red'> Mencionei definições de limites convergentes e divergentes e propriedades de sequências; Example IV
