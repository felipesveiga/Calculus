# %% [markdown]
# <h1 style='font-size:40px'> Differential Equations </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Uma das principais utilidades da matemática seria a predição do valor de um fenômeno considerando mudanças que aconteceram no ambiente do estudo.
#         </li>
#         <li>
#             Nesse contexto, podemos usar Equações Diferenciais para fazermos essa tarefa. Elas consistem numa equação que contém uma função desconhecida juntamente com suas respectivas derivadas.
#         </li>
#         <li>
#             Podemos basear nosso problema em experimentos provados, ou simplesmente em uma ideia gerada por nossa intuição.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> 9.1 Modeling with Differential Equations</h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Começamos essa seção demonstrando alguns exemplos de problemas envolvendo equações diferenciais.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> Crescimento Populacional</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Ao criarmos uma função que estime o tamanho de uma população num tempo $t$, podemos intuir que esse valor se torne cada vez maior, conforme a quantidade de indivíduos cresça.
#         </li>
#         <li>
#             Nesse sentido, podemos expressar matematicamente essa idealização com a seguinte equação, sendo $P$ a função que expressa a quantidade de pessoas pelo tempo.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         $\frac{dP}{dt}=kP \text{, } k\in{\mathbb{R}^{+}}$
#     </center>
# </figure>

# %% [markdown]
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             As funções exponenciais possuem a característica que estamos buscando. Sendo $P(t)=Ce^{kt}$, sua derivada será:
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         $P'(t)=C(ke^{kt})=k(Ce^{kt})=kP(t)$
#     </center>
# </figure>

# %%
# Apenas repare que nosso problema demanda que C>0, para garantir que P(t) cresça conforme t seja maior.
import numpy as np
import matplotlib.pyplot as plt

K = .5
x = np.linspace(0, 10, 1001)

for c in [-10, -5, 1, 5, 10]:
    y = c*np.exp(K*x)
    plt.plot(x,y)

# %% [markdown]
# <h4 style='font-size:30px;font-style:italic;text-decoration:underline'> A Model for the Motion of a Spring</h4>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Sabemos que a força exercida por uma mola sobre um objeto quando essa é comprimida/espremida em $x$ unidades é $-kx$ ($k$ sendo uma constante).
#         </li>
#         <li>
#             Supondo uma situação de condições ideais (sem atrito, resistência do ar), podemos igualar essa equação à Segunda Lei de Newton ($F=m\frac{d^{2}x}{dt^{2}}$).
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         $$
#             m\frac{d^{2}x}{dt^{2}}=-kx \iff \frac{d^{2}x}{dt^{2}}=\frac{-k}{m}x
#         $$
#     </center>
# </figure>

# %% [markdown]
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A equação diferencial acima nos propõe uma função $x$ tal qual sua segunda derivada seja inversamente proporcional a si.
#         </li>
#         <li>
#             Podemos pensar como soluções as funções seno e cosseno. $\frac{d^{2}[\sin{x}]}{dt^{2}}=-\sin{x}$ e $\frac{d^{2}[\cos{x}]}{dt^{2}}=-\cos{x}$.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'> General Differential Equations</h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             A ordem de uma equação diferencial é correspondente ao maior grau das derivadas envolvidas no nosso problema.
#         </li>
#         <li>
#             Portanto, a primeira equação que trabalhamos seria de primeira ordem, enquanto que a outra de segunda.
#         </li>
#         <li>
#             A variável com base na qual extraímos as derivadas é nomeada como a <i> variável independente</i>.
#         </li>
#      </ul>
# </div>

# %%
! git add .
! git commit -am 'Continuar de "General Differential Equations"' 
! git push
# Out:
# [master 376756d] Terminar solução do exemplo de "Crescimento Populacional"
#  2 files changed, 264 insertions(+), 26 deletions(-)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 29.04 KiB | 29.04 MiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/felipesveiga/Calculus.git
#    c9ba400..376756d  master -> master

# %% [markdown]
# <p style='color:red'>Mencionei os exemplos de "Crescimento Populacional" e "A Model for the Motion of a Spring"; Continuar de "General Differential Equations"
